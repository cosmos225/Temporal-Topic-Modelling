# %% [markdown]
# # Data Preprocessing
#
# This notebook builds a master dataframe of financial journals, clean the data, and export data to csv files.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/ML_Trending_Topics/
# Out:
# /content/drive/MyDrive/ML_Trending_Topics

# %%
from nltk.stem.snowball import SnowballStemmer
from sklearn.preprocessing import StandardScaler
from nltk.stem import WordNetLemmatizer
import regex as re
import numpy as np
import pandas as pd
import warnings
import glob
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset

# %% [markdown]
# ### Improved

# %%
# Get data file names
path = 'Dataset'
filenames = glob.glob(path + "/ieee*.csv")

dfs = []
for filename in filenames:
    dfs.append(pd.read_csv(filename, error_bad_lines=False))

# Concatenate all data into one DataFrame
big_frame_csv = pd.concat(dfs, ignore_index=True)
# Out:
# b'Skipping line 4: expected 1 fields, saw 6\nSkipping line 5: expected 1 fields, saw 6\nSkipping line 6: expected 1 fields, saw 6\nSkipping line 7: expected 1 fields, saw 6\nSkipping line 8: expected 1 fields, saw 6\nSkipping line 9: expected 1 fields, saw 6\nSkipping line 10: expected 1 fields, saw 6\nSkipping line 11: expected 1 fields, saw 6\nSkipping line 12: expected 1 fields, saw 6\nSkipping line 13: expected 1 fields, saw 6\nSkipping line 14: expected 1 fields, saw 6\nSkipping line 15: expected 1 fields, saw 6\nSkipping line 16: expected 1 fields, saw 6\nSkipping line 17: expected 1 fields, saw 6\nSkipping line 18: expected 1 fields, saw 6\nSkipping line 19: expected 1 fields, saw 6\nSkipping line 20: expected 1 fields, saw 6\nSkipping line 21: expected 1 fields, saw 6\nSkipping line 22: expected 1 fields, saw 6\nSkipping line 23: expected 1 fields, saw 6\nSkipping line 24: expected 1 fields, saw 6\nSkipping line 25: expected 1 fields, saw 6\nSkipping line 26: expected 1 fields, saw 6\nSkipping line 27: expected 1 fields, saw 6\nSkipping line 28: expected 1 fields, saw 6\nSkipping line 29: expected 1 fields, saw 6\nSkipping line 30: expected 1 fields, saw 6\nSkipping line 31: expected 1 fields, saw 6\nSkipping line 32: expected 1 fields, saw 6\nSkipping line 33: expected 1 fields, saw 6\nSkipping line 34: expected 1 fields, saw 6\nSkipping line 35: expected 1 fields, saw 6\nSkipping line 36: expected 1 fields, saw 6\nSkipping line 37: expected 1 fields, saw 6\nSkipping line 38: expected 1 fields, saw 6\nSkipping line 39: expected 1 fields, saw 6\nSkipping line 40: expected 1 fields, saw 6\nSkipping line 41: expected 1 fields, saw 6\nSkipping line 42: expected 1 fields, saw 6\nSkipping line 43: expected 1 fields, saw 6\nSkipping line 44: expected 1 fields, saw 6\nSkipping line 45: expected 1 fields, saw 6\nSkipping line 46: expected 1 fields, saw 6\nSkipping line 47: expected 1 fields, saw 6\nSkipping line 48: expected 1 fields, saw 6\nSkipping line 49: expected 1 fields, saw 6\nSkipping line 50: expected 1 fields, saw 6\nSkipping line 51: expected 1 fields, saw 6\nSkipping line 52: expected 1 fields, saw 6\nSkipping line 53: expected 1 fields, saw 6\nSkipping line 54: expected 1 fields, saw 6\nSkipping line 55: expected 1 fields, saw 6\nSkipping line 56: expected 1 fields, saw 6\nSkipping line 57: expected 1 fields, saw 6\nSkipping line 58: expected 1 fields, saw 6\nSkipping line 59: expected 1 fields, saw 6\nSkipping line 60: expected 1 fields, saw 6\nSkipping line 61: expected 1 fields, saw 6\nSkipping line 62: expected 1 fields, saw 6\nSkipping line 63: expected 1 fields, saw 6\nSkipping line 64: expected 1 fields, saw 6\nSkipping line 65: expected 1 fields, saw 6\nSkipping line 66: expected 1 fields, saw 6\nSkipping line 67: expected 1 fields, saw 6\nSkipping line 68: expected 1 fields, saw 6\nSkipping line 69: expected 1 fields, saw 6\nSkipping line 70: expected 1 fields, saw 6\nSkipping line 71: expected 1 fields, saw 6\nSkipping line 72: expected 1 fields, saw 6\nSkipping line 73: expected 1 fields, saw 6\nSkipping line 74: expected 1 fields, saw 6\nSkipping line 75: expected 1 fields, saw 6\nSkipping line 76: expected 1 fields, saw 6\nSkipping line 77: expected 1 fields, saw 6\nSkipping line 78: expected 1 fields, saw 6\nSkipping line 79: expected 1 fields, saw 6\nSkipping line 80: expected 1 fields, saw 6\nSkipping line 81: expected 1 fields, saw 6\nSkipping line 82: expected 1 fields, saw 6\nSkipping line 83: expected 1 fields, saw 6\nSkipping line 84: expected 1 fields, saw 6\nSkipping line 85: expected 1 fields, saw 6\nSkipping line 86: expected 1 fields, saw 6\nSkipping line 87: expected 1 fields, saw 6\nSkipping line 88: expected 1 fields, saw 6\nSkipping line 89: expected 1 fields, saw 6\nSkipping line 90: expected 1 fields, saw 6\nSkipping line 91: expected 1 fields, saw 6\nSkipping line 92: expected 1 fields, saw 6\nSkipping line 93: expected 1 fields, saw 6\nSkipping line 94: expected 1 fields, saw 6\n ...
# b'Skipping line 4: expected 1 fields, saw 6\nSkipping line 5: expected 1 fields, saw 6\nSkipping line 6: expected 1 fields, saw 6\nSkipping line 7: expected 1 fields, saw 6\nSkipping line 8: expected 1 fields, saw 6\nSkipping line 9: expected 1 fields, saw 6\nSkipping line 10: expected 1 fields, saw 6\nSkipping line 11: expected 1 fields, saw 6\nSkipping line 12: expected 1 fields, saw 6\nSkipping line 13: expected 1 fields, saw 6\nSkipping line 14: expected 1 fields, saw 6\nSkipping line 15: expected 1 fields, saw 6\nSkipping line 16: expected 1 fields, saw 6\nSkipping line 17: expected 1 fields, saw 6\nSkipping line 18: expected 1 fields, saw 6\nSkipping line 19: expected 1 fields, saw 6\nSkipping line 20: expected 1 fields, saw 6\nSkipping line 21: expected 1 fields, saw 6\nSkipping line 22: expected 1 fields, saw 6\nSkipping line 23: expected 1 fields, saw 6\nSkipping line 24: expected 1 fields, saw 6\nSkipping line 25: expected 1 fields, saw 6\nSkipping line 26: expected 1 fields, saw 6\nSkipping line 27: expected 1 fields, saw 6\nSkipping line 28: expected 1 fields, saw 6\nSkipping line 29: expected 1 fields, saw 6\nSkipping line 30: expected 1 fields, saw 6\nSkipping line 31: expected 1 fields, saw 6\nSkipping line 32: expected 1 fields, saw 6\nSkipping line 33: expected 1 fields, saw 6\nSkipping line 34: expected 1 fields, saw 6\nSkipping line 35: expected 1 fields, saw 6\nSkipping line 36: expected 1 fields, saw 6\nSkipping line 37: expected 1 fields, saw 6\nSkipping line 38: expected 1 fields, saw 6\nSkipping line 39: expected 1 fields, saw 6\nSkipping line 40: expected 1 fields, saw 6\nSkipping line 41: expected 1 fields, saw 6\nSkipping line 42: expected 1 fields, saw 6\nSkipping line 43: expected 1 fields, saw 6\nSkipping line 44: expected 1 fields, saw 6\nSkipping line 45: expected 1 fields, saw 6\nSkipping line 46: expected 1 fields, saw 6\nSkipping line 47: expected 1 fields, saw 6\nSkipping line 48: expected 1 fields, saw 6\nSkipping line 49: expected 1 fields, saw 6\nSkipping line 50: expected 1 fields, saw 6\nSkipping line 51: expected 1 fields, saw 6\nSkipping line 52: expected 1 fields, saw 6\nSkipping line 53: expected 1 fields, saw 6\nSkipping line 54: expected 1 fields, saw 6\nSkipping line 55: expected 1 fields, saw 6\nSkipping line 56: expected 1 fields, saw 6\nSkipping line 57: expected 1 fields, saw 6\nSkipping line 58: expected 1 fields, saw 6\nSkipping line 59: expected 1 fields, saw 6\nSkipping line 60: expected 1 fields, saw 6\nSkipping line 61: expected 1 fields, saw 6\nSkipping line 62: expected 1 fields, saw 6\nSkipping line 63: expected 1 fields, saw 6\nSkipping line 64: expected 1 fields, saw 6\nSkipping line 65: expected 1 fields, saw 6\nSkipping line 66: expected 1 fields, saw 6\nSkipping line 67: expected 1 fields, saw 6\nSkipping line 68: expected 1 fields, saw 6\nSkipping line 69: expected 1 fields, saw 6\nSkipping line 70: expected 1 fields, saw 6\nSkipping line 71: expected 1 fields, saw 6\nSkipping line 72: expected 1 fields, saw 6\nSkipping line 73: expected 1 fields, saw 6\nSkipping line 74: expected 1 fields, saw 6\nSkipping line 75: expected 1 fields, saw 6\nSkipping line 76: expected 1 fields, saw 6\nSkipping line 77: expected 1 fields, saw 6\nSkipping line 78: expected 1 fields, saw 6\nSkipping line 79: expected 1 fields, saw 6\nSkipping line 80: expected 1 fields, saw 6\nSkipping line 81: expected 1 fields, saw 6\nSkipping line 82: expected 1 fields, saw 6\nSkipping line 83: expected 1 fields, saw 6\nSkipping line 84: expected 1 fields, saw 6\nSkipping line 85: expected 1 fields, saw 6\nSkipping line 86: expected 1 fields, saw 6\nSkipping line 87: expected 1 fields, saw 6\nSkipping line 88: expected 1 fields, saw 6\nSkipping line 89: expected 1 fields, saw 6\nSkipping line 90: expected 1 fields, saw 6\nSkipping line 91: expected 1 fields, saw 6\nSkipping line 92: expected 1 fields, saw 6\nSkipping line 93: expected 1 fields, saw 6\nSkipping line 94: expected 1 fields, saw 6\n ...

# %%
# Get data file names
path = 'Dataset'
filenames = glob.glob(path + "/ieee*.xlsx")

dfs = []
for filename in filenames:
    dfs.append(pd.read_excel(filename))

# Concatenate all data into one DataFrame
big_frame_xl = pd.concat(dfs, ignore_index=True)

# %%
filenames
# Out:
# ['Dataset/ieeexplore-2023.xlsx',
#  'Dataset/ieeexplore2010-2014.xlsx',
#  'Dataset/ieee2010-2022-2.csv.xlsx',
#  'Dataset/ieeexplore2010-2022.xlsx',
#  'Dataset/ieee2015-2022-6.xlsx',
#  'Dataset/ieee2015-2022-5.xlsx']

# %%
big_frame_xl['year'].unique()
# Out:
# array([2023., 2022., 2010., 2011., 2012., 2013., 2014., 2021., 2020.,
#        2019., 2017., 2018., 2015., 2016.])

# %%
big_frame_xl['year'] = big_frame_xl['year'].astype(int)
big_frame_xl
# Out:
#                                                  Authors  \
# 0      Chen Zhang; Haodi Zhang; Qifan Li; Kaishun Wu;...
# 1                       Hongjie Cai; Yue Gao; Manhua Liu
# 2      Premkumar Chithaluru; Fadi AL-Turjman; Manoj K...
# 3      Mads Olsen; Jamie M. Zeitzer; Risa N. Richards...
# 4      Jeongseok Hyun; Myunggu Kang; Dongyoon Wee; Di...
# ...                                                  ...
# 10199                                Henter GE,Kleijn WB
# 10200                         Wang T,Gong S,Zhu X,Wang S
# 10201  Türetken E,Benmansour F,Andres B,Głowacki P,Pf...
# 10202                            Venkataraman V,Turaga P
# 10203                           Leifman G,Shtrom E,Tal A
#
#                                                    Title  year     month  \
# 0      Burstiness-Aware Web Search Analysis on Differ...  2023     March
# 1      Graph Transformer Geometric Learning of Brain ...  2023  February
# 2      Computational Intelligence Inspired Adaptive O...  2023   January
# 3      A Flexible Deep Learning Architecture for Temp...  2023   January
# 4      Detection Recovery in Online Multi-Object Trac...  2023  February
# ...                                                  ...   ...       ...
# 10199  Minimum Entropy Rate Simplification of Stochas...  2016  December
# 10200  Person Re-Identification by Discriminative Sel...  2016  December
# 10201  Reconstructing Curvilinear Networks Using Path...  2016  December
# 10202  Shape Distributions of Nonlinear Dynamical Sys...  2016  December
# 10203  Surface Regions of Interest for Viewpoint Sele...  2016  December
#
#                                                 Abstract  \
# 0      Personalizing the analysis for web search pote...
# 1      Brain age is considered as an important biomar...
# 2      The major issues and challenges of the Industr...
# 3      Wrist-worn consumer sleep technologies (CST) t...
# 4      In existing joint detection and tracking metho...
# ...                                                  ...
# 10199  We propose minimum entropy rate simplification...
# 10200  Current person re-identification (ReID) method...
# 10201  We propose a novel approach to automated delin...
# 10202  This paper presents a shape-theoretic framewor...
# 10203  While the detection of the interesting regions...
#
#                                                 Keywords Unnamed: 6  \
# 0      Web search , Biological system modeling , Comp...        NaN
# 1      Estimation , Diffusion tensor imaging , Transf...        NaN
# 2      Industrial Internet of Things , Peer-to-peer c...        NaN
# 3      Recording , Sleep apnea , Deep learning , Deco...        NaN
# 4      Computer vision , Target tracking , Codes , Im...        NaN
# ...                                                  ...        ...
# 10199  Markov processes;Stochastic processes;Gaussian...        NaN
# 10200  Image sequences;Cameras;Gait recognition;Visua...        NaN
# 10201  Linear programming;Image reconstruction;Curvil...        NaN
# 10202  Chaos theory;Hidden Markov models;Analytical m...        NaN
# 10203  Three-dimensional displays;Surface treatment;H...        NaN
#
#        Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0             NaN        NaN        NaN         NaN
# 1             NaN        NaN        NaN         NaN
# 2             NaN        NaN        NaN         NaN
# 3             NaN        NaN        NaN         NaN
# 4             NaN        NaN        NaN         NaN
# ...           ...        ...        ...         ...
# 10199         NaN        NaN        NaN         NaN
# 10200         NaN        NaN        NaN         NaN
# 10201         NaN        NaN        NaN         NaN
# 10202         NaN        NaN        NaN         NaN
# 10203         NaN        NaN        NaN         NaN
#
# [10204 rows x 11 columns]

# %%
big_frame_csv.drop(columns = ['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', '# CSV-File created with merge-csv.com'], inplace=True)

# %%
big_frame_csv
# Out:
#                                                  Authors  \
# 0                                    Xu X,Cheong LF,Li Z
# 1                                      Johnson R,Zhang T
# 2                  Fan Q,Chen D,Yuan L,Hua G,Yu N,Chen B
# 3                Chen L,Zheng Y,Shi B,Subpa-asa A,Sato I
# 4                                       Zhou Y,Cheung YM
# ...                                                  ...
# 10101                         Wang T,Gong S,Zhu X,Wang S
# 10102  Türetken E,Benmansour F,Andres B,Głowacki P,Pf...
# 10103                            Venkataraman V,Turaga P
# 10104                           Leifman G,Shtrom E,Tal A
# 10105                                                NaN
#
#                                                    Title    year     month  \
# 0      3D Rigid Motion Segmentation with Mixed and Un...  2021.0   January
# 1      A Framework of Composite Functional Gradient M...  2021.0   January
# 2      A General Decoupled Learning Framework for Par...  2021.0   January
# 3      A Microfacet-Based Model for Photometric Stere...  2021.0   January
# 4      Bayesian Low-Tubal-Rank Robust Tensor Factoriz...  2021.0   January
# ...                                                  ...     ...       ...
# 10101  Person Re-Identification by Discriminative Sel...  2016.0  December
# 10102  Reconstructing Curvilinear Networks Using Path...  2016.0  December
# 10103  Shape Distributions of Nonlinear Dynamical Sys...  2016.0  December
# 10104  Surface Regions of Interest for Viewpoint Sele...  2016.0  December
# 10105                                                NaN     NaN       NaN
#
#                                                 Abstract  \
# 0      Many real-world video sequences cannot be conv...
# 1      Generative adversarial networks (GAN) are trai...
# 2      Many different deep networks have been used to...
# 3      This paper presents a precise, stable, and inv...
# 4      Robust tensor factorization is a fundamental p...
# ...                                                  ...
# 10101  Current person re-identification (ReID) method...
# 10102  We propose a novel approach to automated delin...
# 10103  This paper presents a shape-theoretic framewor...
# 10104  While the detection of the interesting regions...
# 10105                                                NaN
#
#                                                 Keywords
# 0      Motion segmentation,Computer vision,Transmissi...
# 1      Generative adversarial networks,Generators,Gal...
# 2      Convolution,Task analysis,Image resolution,Acc...
# 3      Ellipsoids,Shape,Rendering (computer graphics)...
# 4      Bayes methods,Principal component analysis,Ada...
# ...                                                  ...
# 10101  Image sequences,Cameras,Gait recognition,Visua...
# 10102  Linear programming,Image reconstruction,Curvil...
# 10103  Chaos theory,Hidden Markov models,Analytical m...
# 10104  Three-dimensional displays,Surface treatment,H...
# 10105                                                NaN
#
# [10106 rows x 6 columns]

# %%
big_frame_xl.drop(columns = ['Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], inplace=True)

# %%
list_df = pd.concat([big_frame_csv, big_frame_xl], ignore_index=True)

# %%
list_df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Original

# %%
'''# get a list of csv file in folder Dataset
dataset_p = 'Dataset/ieee2015-2022-6.csv'

# read each csv file into a Pandas dataframe
# and store the dataframes into a list
list_df = pd.read_csv(dataset_p, encoding="ISO-8859-1") 

# display number of dataframes created
# print("Number of Data Frames:", len(list_df))

# look at the first dataframe
list_df'''
# Out:
# '# get a list of csv file in folder Dataset\ndataset_p = \'Dataset/ieee2015-2022-6.csv\'\n\n# read each csv file into a Pandas dataframe\n# and store the dataframes into a list\nlist_df = pd.read_csv(dataset_p, encoding="ISO-8859-1") \n\n# display number of dataframes created\n# print("Number of Data Frames:", len(list_df))\n\n# look at the first dataframe\nlist_df'

# %%
list_df.head()
# Out:
#                                    Authors  \
# 0                      Xu X,Cheong LF,Li Z
# 1                        Johnson R,Zhang T
# 2    Fan Q,Chen D,Yuan L,Hua G,Yu N,Chen B
# 3  Chen L,Zheng Y,Shi B,Subpa-asa A,Sato I
# 4                         Zhou Y,Cheung YM
#
#                                                Title    year    month  \
# 0  3D Rigid Motion Segmentation with Mixed and Un...  2021.0  January
# 1  A Framework of Composite Functional Gradient M...  2021.0  January
# 2  A General Decoupled Learning Framework for Par...  2021.0  January
# 3  A Microfacet-Based Model for Photometric Stere...  2021.0  January
# 4  Bayesian Low-Tubal-Rank Robust Tensor Factoriz...  2021.0  January
#
#                                             Abstract  \
# 0  Many real-world video sequences cannot be conv...
# 1  Generative adversarial networks (GAN) are trai...
# 2  Many different deep networks have been used to...
# 3  This paper presents a precise, stable, and inv...
# 4  Robust tensor factorization is a fundamental p...
#
#                                             Keywords
# 0  Motion segmentation,Computer vision,Transmissi...
# 1  Generative adversarial networks,Generators,Gal...
# 2  Convolution,Task analysis,Image resolution,Acc...
# 3  Ellipsoids,Shape,Rendering (computer graphics)...
# 4  Bayes methods,Principal component analysis,Ada...

# %%
# list_df.drop('Unnamed: 10', axis=1, inplace=True)

# %%
list_df
# Out:
#                                                  Authors  \
# 0                                    Xu X,Cheong LF,Li Z
# 1                                      Johnson R,Zhang T
# 2                  Fan Q,Chen D,Yuan L,Hua G,Yu N,Chen B
# 3                Chen L,Zheng Y,Shi B,Subpa-asa A,Sato I
# 4                                       Zhou Y,Cheung YM
# ...                                                  ...
# 20305                                Henter GE,Kleijn WB
# 20306                         Wang T,Gong S,Zhu X,Wang S
# 20307  Türetken E,Benmansour F,Andres B,Głowacki P,Pf...
# 20308                            Venkataraman V,Turaga P
# 20309                           Leifman G,Shtrom E,Tal A
#
#                                                    Title    year     month  \
# 0      3D Rigid Motion Segmentation with Mixed and Un...  2021.0   January
# 1      A Framework of Composite Functional Gradient M...  2021.0   January
# 2      A General Decoupled Learning Framework for Par...  2021.0   January
# 3      A Microfacet-Based Model for Photometric Stere...  2021.0   January
# 4      Bayesian Low-Tubal-Rank Robust Tensor Factoriz...  2021.0   January
# ...                                                  ...     ...       ...
# 20305  Minimum Entropy Rate Simplification of Stochas...  2016.0  December
# 20306  Person Re-Identification by Discriminative Sel...  2016.0  December
# 20307  Reconstructing Curvilinear Networks Using Path...  2016.0  December
# 20308  Shape Distributions of Nonlinear Dynamical Sys...  2016.0  December
# 20309  Surface Regions of Interest for Viewpoint Sele...  2016.0  December
#
#                                                 Abstract  \
# 0      Many real-world video sequences cannot be conv...
# 1      Generative adversarial networks (GAN) are trai...
# 2      Many different deep networks have been used to...
# 3      This paper presents a precise, stable, and inv...
# 4      Robust tensor factorization is a fundamental p...
# ...                                                  ...
# 20305  We propose minimum entropy rate simplification...
# 20306  Current person re-identification (ReID) method...
# 20307  We propose a novel approach to automated delin...
# 20308  This paper presents a shape-theoretic framewor...
# 20309  While the detection of the interesting regions...
#
#                                                 Keywords
# 0      Motion segmentation,Computer vision,Transmissi...
# 1      Generative adversarial networks,Generators,Gal...
# 2      Convolution,Task analysis,Image resolution,Acc...
# 3      Ellipsoids,Shape,Rendering (computer graphics)...
# 4      Bayes methods,Principal component analysis,Ada...
# ...                                                  ...
# 20305  Markov processes;Stochastic processes;Gaussian...
# 20306  Image sequences;Cameras;Gait recognition;Visua...
# 20307  Linear programming;Image reconstruction;Curvil...
# 20308  Chaos theory;Hidden Markov models;Analytical m...
# 20309  Three-dimensional displays;Surface treatment;H...
#
# [4642 rows x 6 columns]

# %%
list_df['year_con'] = pd.to_numeric(list_df.year,errors='coerce')

# %%
list_df['year_con'].std()
# Out:
# 3.5765036792015263

# %%
# merge all dataframes into a master dataframe
df_master = list_df

# drop rows that have missing values
df_master.dropna(axis=0, how='any',inplace=True)

# get the name of first author
df_master['author_first'] = df_master.Authors.apply(lambda x: x[1:-1].split(',')[0][1:-1])

# duplicate Year
df_master['year_master'] = df_master['year_con'].copy()

# compute the standard deviation for Year
df_master['year_std'] = df_master['year_con'] / df_master['year_con'].std()

# apply standard scaler on Year
df_master['year_con'] = StandardScaler().fit_transform(df_master['year_con'].values.reshape(-1, 1))

# display the shape of df_masters
print("Data's shape: ", df_master.shape)

# look at df_master
df_master.head()
# Out:
# Data's shape:  (4604, 10)
#                                    Authors  \
# 0                      Xu X,Cheong LF,Li Z
# 1                        Johnson R,Zhang T
# 2    Fan Q,Chen D,Yuan L,Hua G,Yu N,Chen B
# 3  Chen L,Zheng Y,Shi B,Subpa-asa A,Sato I
# 4                         Zhou Y,Cheung YM
#
#                                                Title    year    month  \
# 0  3D Rigid Motion Segmentation with Mixed and Un...  2021.0  January
# 1  A Framework of Composite Functional Gradient M...  2021.0  January
# 2  A General Decoupled Learning Framework for Par...  2021.0  January
# 3  A Microfacet-Based Model for Photometric Stere...  2021.0  January
# 4  Bayesian Low-Tubal-Rank Robust Tensor Factoriz...  2021.0  January
#
#                                             Abstract  \
# 0  Many real-world video sequences cannot be conv...
# 1  Generative adversarial networks (GAN) are trai...
# 2  Many different deep networks have been used to...
# 3  This paper presents a precise, stable, and inv...
# 4  Robust tensor factorization is a fundamental p...
#
#                                             Keywords  year_con author_first  \
# 0  Motion segmentation,Computer vision,Transmissi...  0.999594
# 1  Generative adversarial networks,Generators,Gal...  0.999594       hnson
# 2  Convolution,Task analysis,Image resolution,Acc...  0.999594           n
# 3  Ellipsoids,Shape,Rendering (computer graphics)...  0.999594          en
# 4  Bayes methods,Principal component analysis,Ada...  0.999594          ou
#
#    year_master    year_std
# 0       2021.0  566.928668
# 1       2021.0  566.928668
# 2       2021.0  566.928668
# 3       2021.0  566.928668
# 4       2021.0  566.928668

# %% [markdown]
# ## Data Preprocessing & Cleaning

# %% [markdown]
# #### Original

# %%
'''import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))  
p = re.compile(r'[^\w\s]+')
lemmatizer = WordNetLemmatizer()
stemmer = SnowballStemmer("english")
df_master['t'] = df_master.Abstract.map(lambda x: ' '.join([stemmer.stem(y) for y in x.split(' ')]))
df_master['t'] = df_master.t.map(lambda x: ' '.join([y for y in x.split(' ') if not y in stops]))
df_master['t'] = df_master.t.map(lambda x: ' '.join([p.sub('', x) for x in x.split(' ')]))
df_master.head()'''
# Out:
# 'import nltk\nnltk.download(\'stopwords\')\nfrom nltk.corpus import stopwords\nstops = set(stopwords.words("english"))  \np = re.compile(r\'[^\\w\\s]+\')\nlemmatizer = WordNetLemmatizer()\nstemmer = SnowballStemmer("english")\ndf_master[\'t\'] = df_master.Abstract.map(lambda x: \' \'.join([stemmer.stem(y) for y in x.split(\' \')]))\ndf_master[\'t\'] = df_master.t.map(lambda x: \' \'.join([y for y in x.split(\' \') if not y in stops]))\ndf_master[\'t\'] = df_master.t.map(lambda x: \' \'.join([p.sub(\'\', x) for x in x.split(\' \')]))\ndf_master.head()'

# %% [markdown]
# #### Improved

# %%
import nltk
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))  
p = re.compile(r'[^\w\s]+')
lemmatizer = WordNetLemmatizer()
df_master['t'] = df_master.Abstract.map(lambda x: ' '.join([lemmatizer.lemmatize(y) for y in x.split(' ')]))
df_master['t'] = df_master.t.map(lambda x: ' '.join([y for y in x.split(' ') if not y in stops]))
df_master['t'] = df_master.t.map(lambda x: ' '.join([p.sub(' ', x) for x in x.split(' ')]))
df_master.head()
# Out:
#                                    Authors  \
# 0                      Xu X,Cheong LF,Li Z
# 1                        Johnson R,Zhang T
# 2    Fan Q,Chen D,Yuan L,Hua G,Yu N,Chen B
# 3  Chen L,Zheng Y,Shi B,Subpa-asa A,Sato I
# 4                         Zhou Y,Cheung YM
#
#                                                Title    year    month  \
# 0  3D Rigid Motion Segmentation with Mixed and Un...  2021.0  January
# 1  A Framework of Composite Functional Gradient M...  2021.0  January
# 2  A General Decoupled Learning Framework for Par...  2021.0  January
# 3  A Microfacet-Based Model for Photometric Stere...  2021.0  January
# 4  Bayesian Low-Tubal-Rank Robust Tensor Factoriz...  2021.0  January
#
#                                             Abstract  \
# 0  Many real-world video sequences cannot be conv...
# 1  Generative adversarial networks (GAN) are trai...
# 2  Many different deep networks have been used to...
# 3  This paper presents a precise, stable, and inv...
# 4  Robust tensor factorization is a fundamental p...
#
#                                             Keywords  year_con author_first  \
# 0  Motion segmentation,Computer vision,Transmissi...  0.999594
# 1  Generative adversarial networks,Generators,Gal...  0.999594       hnson
# 2  Convolution,Task analysis,Image resolution,Acc...  0.999594           n
# 3  Ellipsoids,Shape,Rendering (computer graphics)...  0.999594          en
# 4  Bayes methods,Principal component analysis,Ada...  0.999594          ou
#
#    year_master    year_std                                                  t
# 0       2021.0  566.928668  Many real world video sequence cannot convenie...
# 1       2021.0  566.928668  Generative adversarial network  GAN  trained m...
# 2       2021.0  566.928668  Many different deep network used approximate  ...
# 3       2021.0  566.928668  This paper present precise  stable  invertible...
# 4       2021.0  566.928668  Robust tensor factorization fundamental proble...

# %% [markdown]
# #### Original

# %%
'''import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

stops = set(stopwords.words("english"))    # get unique English stopwords
regex = re.compile(r'[^\w\s]+')            # regular expression pattern
stemmer = SnowballStemmer("english")       # create a Snowball Stemmer object for stemming

  
lemmatizer = WordNetLemmatizer()
  
# duplicate a subset of the master dataframe
df = df_master[['year_master', 'year', 'year_std','month', 'Keywords', 'Abstract']]
df.rename(columns={'year_master': 'Year', 'year': 'Year_Scaled', 
                   'year_std': 'Year_STD','month': 'Month',  'Keywords': 'Keywords',
                   'abstract': 'Abstract'}, inplace=True)

# clean the abstract
df['Abstract_Cleaned'] = df.Abstract.map(lambda x: ' '.join([lemmatizer.lemmatize(y) for y in x.split(' ')]))
df['Abstract_Cleaned'] = df.Abstract_Cleaned.map(lambda x: ' '.join([y for y in x.split(' ') if not y in stops]))
# df['Abstract_Cleaned'] = df.Abstract_Cleaned.map(lambda x: ' '.join([regex.sub('', x) for x in x.split(' ')]))

# get the length of the abstract
df['Abstract Length'] = df.Abstract.str.len()'''
# Out:
# 'import nltk\nnltk.download(\'stopwords\')\nfrom nltk.corpus import stopwords\nimport re\nimport nltk\nnltk.download(\'wordnet\')\nnltk.download(\'omw-1.4\')\n\nstops = set(stopwords.words("english"))    # get unique English stopwords\nregex = re.compile(r\'[^\\w\\s]+\')            # regular expression pattern\nstemmer = SnowballStemmer("english")       # create a Snowball Stemmer object for stemming\n\n  \nlemmatizer = WordNetLemmatizer()\n  \n# duplicate a subset of the master dataframe\ndf = df_master[[\'year_master\', \'year\', \'year_std\',\'month\', \'Keywords\', \'Abstract\']]\ndf.rename(columns={\'year_master\': \'Year\', \'year\': \'Year_Scaled\', \n                   \'year_std\': \'Year_STD\',\'month\': \'Month\',  \'Keywords\': \'Keywords\',\n                   \'abstract\': \'Abstract\'}, inplace=True)\n\n# clean the abstract\ndf[\'Abstract_Cleaned\'] = df.Abstract.map(lambda x: \' \'.join([lemmatizer.lemmatize(y) for y in x.split(\' \')]))\ndf[\'Abstract_Cleaned\'] = df.Abstract_Cleaned.map(lambda x: \' \'.join([y for y in x.split(\' \') if not y in stops]))\n# df[\'Abstract_Cleaned\'] = df.Abstract_Cleaned.map(lambda x: \' \'.join([regex.sub(\'\', x) for x in x.split(\' \')]))\n\n# get the length of the abstract\ndf[\'Abstract Length\'] = df.Abstract.str.len()'

# %% [markdown]
# #### Improved

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import re
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

stops = set(stopwords.words("english"))    # get unique English stopwords
regex = re.compile(r'[^\w\s]+')            # regular expression pattern
stemmer = SnowballStemmer("english")       # create a Snowball Stemmer object for stemming

  
lemmatizer = WordNetLemmatizer()
  
# duplicate a subset of the master dataframe
df = df_master[['year_master', 'year', 'year_std','month', 'Keywords', 'Abstract']]
df.rename(columns={'year_master': 'Year', 'year': 'Year_Scaled', 
                   'year_std': 'Year_STD','month': 'Month',  'Keywords': 'Keywords',
                   'abstract': 'Abstract'}, inplace=True)

# clean the abstract
df['Abstract_Cleaned'] = df.Abstract.map(lambda x: ' '.join([lemmatizer.lemmatize(y) for y in x.split(' ')]))
df['Abstract_Cleaned'] = df.Abstract_Cleaned.map(lambda x: ' '.join([y for y in x.split(' ') if not y in stops]))
df['Abstract_Cleaned'] = df.Abstract_Cleaned.map(lambda x: ' '.join([regex.sub('', x) for x in x.split(' ')]))
df['Keywords'] = df['Keywords'].replace('[()]', ',', regex=True)
df['Keywords'] = df['Keywords'].replace('\$360\^\\\\circ\s360\sâ\\x88\\x98', ',', regex=True)
# get the length of the abstract
df['Abstract Length'] = df.Abstract.str.len()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df
# Out:
#          Year  Year_Scaled    Year_STD     Month  \
# 0      2021.0       2021.0  566.928668   January
# 1      2021.0       2021.0  566.928668   January
# 2      2021.0       2021.0  566.928668   January
# 3      2021.0       2021.0  566.928668   January
# 4      2021.0       2021.0  566.928668   January
# ...       ...          ...         ...       ...
# 20305  2016.0       2016.0  565.526073  December
# 20306  2016.0       2016.0  565.526073  December
# 20307  2016.0       2016.0  565.526073  December
# 20308  2016.0       2016.0  565.526073  December
# 20309  2016.0       2016.0  565.526073  December
#
#                                                 Keywords  \
# 0      Motion segmentation,Computer vision,Transmissi...
# 1      Generative adversarial networks,Generators,Gal...
# 2      Convolution,Task analysis,Image resolution,Acc...
# 3      Ellipsoids,Shape,Rendering ,computer graphics,...
# 4      Bayes methods,Principal component analysis,Ada...
# ...                                                  ...
# 20305  Markov processes;Stochastic processes;Gaussian...
# 20306  Image sequences;Cameras;Gait recognition;Visua...
# 20307  Linear programming;Image reconstruction;Curvil...
# 20308  Chaos theory;Hidden Markov models;Analytical m...
# 20309  Three-dimensional displays;Surface treatment;H...
#
#                                                 Abstract  \
# 0      Many real-world video sequences cannot be conv...
# 1      Generative adversarial networks (GAN) are trai...
# 2      Many different deep networks have been used to...
# 3      This paper presents a precise, stable, and inv...
# 4      Robust tensor factorization is a fundamental p...
# ...                                                  ...
# 20305  We propose minimum entropy rate simplification...
# 20306  Current person re-identification (ReID) method...
# 20307  We propose a novel approach to automated delin...
# 20308  This paper presents a shape-theoretic framewor...
# 20309  While the detection of the interesting regions...
#
#                                         Abstract_Cleaned  Abstract Length
# 0      Many realworld video sequence cannot convenien...             1594
# 1      Generative adversarial network GAN trained min...              955
# 2      Many different deep network used approximate a...             1393
# 3      This paper present precise stable invertible r...              914
# 4      Robust tensor factorization fundamental proble...             1300
# ...                                                  ...              ...
# 20305  We propose minimum entropy rate simplification...             1298
# 20306  Current person reidentification ReID method ty...             1095
# 20307  We propose novel approach automated delineatio...              951
# 20308  This paper present shapetheoretic framework dy...             1701
# 20309  While detection interesting region image ha ex...              731
#
# [4604 rows x 8 columns]

# %%
df['Abstract_Cleaned']=df_master['t']

# %% [markdown]
# #### Original

# %%
'''def stem_keywords(keywords):
    # create an empty list of keywords
    kw_list = []
    
    # iterate through each keyword in the list and apply stemming
    for kw in keywords[1:-1].split(', '):
        # stem each word in the  keyword
        stemmed_kw = ' '.join(lemmatizer.lemmatize(word) for word in kw.split(' '))
        kw_list.append(stemmed_kw)
    
    return kw_list


# apply stemming to Keywords
df['Keywords_Cleaned'] = df['Keywords'].apply(stem_keywords)'''
# Out:
# "def stem_keywords(keywords):\n    # create an empty list of keywords\n    kw_list = []\n    \n    # iterate through each keyword in the list and apply stemming\n    for kw in keywords[1:-1].split(', '):\n        # stem each word in the  keyword\n        stemmed_kw = ' '.join(lemmatizer.lemmatize(word) for word in kw.split(' '))\n        kw_list.append(stemmed_kw)\n    \n    return kw_list\n\n\n# apply stemming to Keywords\ndf['Keywords_Cleaned'] = df['Keywords'].apply(stem_keywords)"

# %% [markdown]
# #### Improved

# %%
def stem_keywords(keywords):
    # create an empty list of keywords
    kw_list = []
    
    # iterate through each keyword in the list and apply stemming
    for kw in keywords[0:].split(', '):
        # stem each word in the  keyword
        stemmed_kw = ' '.join(lemmatizer.lemmatize(word) for word in kw.split(' '))
        kw_list.append(kw)
    
    return kw_list


# apply stemming to Keywords
df['Keywords_Cleaned'] = df['Keywords'].apply(stem_keywords)
df['Keywords_Cleaned'] = df['Keywords_Cleaned'].str.replace(r'(?<=\w)-', ' - ').str.replace(';', ', ').str.replace(r'[^\w\s,]', '')
df['Keywords_Cleaned']= df['Keywords_Cleaned'].str.replace(r',\s*,', ',').str.replace(r'[^\w\s,]', '')

# %% [markdown]
# #### Improved - Dataframe index and number of keywords were inconsistent

# %%
df = df.reset_index(drop=True)

# %%
for i in range(0,len(df)):
  df['Keywords_Cleaned'][i] = df['Keywords_Cleaned'][i][0].split(',')

# %%
len(df['Keywords_Cleaned'][0])
# Out:
# 11

# %%
len(df['Keywords_Cleaned'][0])
# Out:
# 11

# %%
# count number of keywords
df['Number of Keywords'] = df['Keywords_Cleaned'].map(lambda keywords: \
                                                      0 if str(keywords) == "['']" else len(keywords))

# %%
# def stem_authors(authors):
#     # create an empty list of keywords
#     kw_list = []
    
#     # iterate through each keyword in the list and apply stemming
#     for kw in authors[1:-1].split(', '):
#         # stem each word in the  keyword
#         stemmed_kw = ' '.join(kw.split(' '))
#         kw_list.append(stemmed_kw)
    
#     return kw_list


# # apply stemming to Keywords
# df['Authors'] = df['Authors'].apply(stem_authors)

# %% [markdown]
# ### Month

# %%
df['Month'] = df['Month'].replace('â\x80\x93', '-', regex=True)

# %%
# display unique value of month
df['Month'].unique()
# Out:
# array(['January', 'February', 'March', 'April', 'May', 'June', 'July',
#        'August', 'September', 'October', 'November', 'December'],
#       dtype=object)

# %%
import calendar

def process_month(month):
    '''
    - Convert month name to numeric value
    - Set any invalid month value to -1
    '''
    
    # extract month from a string
    month_extracted = month.split('-')[-1]
    
    # assume month's value is invalid
    month_numeric = -1
    
    if month_extracted.isnumeric() and int(month_extracted) in np.arange(1, 13):
        # month_extracted has value between 1 and 12
        month_numeric = int(month_extracted)
    elif not month_extracted.isnumeric():
        # month_extracted have text value "January" to "December"
        month_numeric = list(calendar.month_name).index(month_extracted)
        
    return month_numeric

# %%
# clean month value
df['Month_Cleaned'] = df['Month'].map(process_month)

# take a look at data
df['Year'] = df['Year'].astype(int)
df['Year_Scaled'] = df['Year_Scaled'].astype(int)
df.head()
# Out:
#    Year  Year_Scaled    Year_STD    Month  \
# 0  2021         2021  566.928668  January
# 1  2021         2021  566.928668  January
# 2  2021         2021  566.928668  January
# 3  2021         2021  566.928668  January
# 4  2021         2021  566.928668  January
#
#                                             Keywords  \
# 0  Motion segmentation,Computer vision,Transmissi...
# 1  Generative adversarial networks,Generators,Gal...
# 2  Convolution,Task analysis,Image resolution,Acc...
# 3  Ellipsoids,Shape,Rendering ,computer graphics,...
# 4  Bayes methods,Principal component analysis,Ada...
#
#                                             Abstract  \
# 0  Many real-world video sequences cannot be conv...
# 1  Generative adversarial networks (GAN) are trai...
# 2  Many different deep networks have been used to...
# 3  This paper presents a precise, stable, and inv...
# 4  Robust tensor factorization is a fundamental p...
#
#                                     Abstract_Cleaned  Abstract Length  \
# 0  Many real world video sequence cannot convenie...             1594
# 1  Generative adversarial network  GAN  trained m...              955
# 2  Many different deep network used approximate  ...             1393
# 3  This paper present precise  stable  invertible...              914
# 4  Robust tensor factorization fundamental proble...             1300
#
#                                     Keywords_Cleaned  Number of Keywords  \
# 0  [Motion segmentation, Computer vision, Transmi...                  11
# 1  [Generative adversarial networks, Generators, ...                  11
# 2  [Convolution, Task analysis, Image resolution,...                  11
# 3  [Ellipsoids, Shape, Rendering , computer graph...                  12
# 4  [Bayes methods, Principal component analysis, ...                  11
#
#    Month_Cleaned
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %% [markdown]
# ## Export Data

# %%
df['Keywords_Cleaned'][0]
# Out:
# ['Motion segmentation',
#  'Computer vision',
#  'Transmission line matrix methods',
#  'Threedimensional displays',
#  'Adaptation models',
#  'Solid modeling',
#  'Data models',
#  'Spectral clustering',
#  'model selection',
#  'motion segmentation',
#  'multiview learning']

# %%
#df_master.to_csv('extracted_files/data_master.csv', index=False)               # save master data
#df.to_csv('extracted_files/data_cleaned.csv', index=False)                    # save cleaned data

# %%
df_master.to_csv('extracted_files/data_master.csv', index=False)               # save master data
df.to_csv('extracted_files/data_cleaned.csv', index=False)                    # save cleaned data
